# %%
#import all the required libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy
import math

# %%
DATA_PATH = "Data/HTRU_2.csv"

data = pd.read_csv(DATA_PATH)

# %%
# make the correlation heatmaps on imbalanced scaled data

corr_matrix = data.corr()

corr_matrix.style.background_gradient(cmap='YlGn').set_precision(2)
# Out:
# <style  type="text/css" >
#     #T_8c2afd1c_7a66_11eb_825a_e8d0fc9c55d2row0_col0 {
#             background-color:  #004529;
#             color:  #f1f1f1;
#         }    #T_8c2afd1c_7a66_11eb_825a_e8d0fc9c55d2row0_col1 {
#             background-color:  #2e924c;
#             color:  #000000;
#         }    #T_8c2afd1c_7a66_11eb_825a_e8d0fc9c55d2row0_col2 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_8c2afd1c_7a66_11eb_825a_e8d0fc9c55d2row0_col3 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_8c2afd1c_7a66_11eb_825a_e8d0fc9c55d2row0_col4 {
#             background-color:  #e6f5ac;
#             color:  #000000;
#         }    #T_8c2afd1c_7a66_11eb_825a_e8d0fc9c55d2row0_col5 {
#             background-color:  #cfec9e;
#             color:  #000000;
#         }    #T_8c2afd1c_7a66_11eb_825a_e8d0fc9c55d2row0_col6 {
#             background-color:  #56b568;
#             color:  #000000;
#         }    #T_8c2afd1c_7a66_11eb_825a_e8d0fc9c55d2row0_col7 {
#             background-color:  #8bce81;
#             color:  #000000;
#         }    #T_8c2afd1c_7a66_11eb_825a_e8d0fc9c55d2row0_col8 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_8c2afd1c_7a66_11eb_825a_e8d0fc9c55d2row1_col0 {
#             background-color:  #208242;
#             color:  #f1f1f1;
#         }    #T_8c2afd1c_7a66_11eb_825a_e8d0fc9c55d2row1_col1 {
#             background-color:  #004529;
#             color:  #f1f1f1;
#         }    #T_8c2afd1c_7a66_11eb_825a_e8d0fc9c55d2row1_col2 {
#             background-color:  #e8f6ae;
#             color:  #000000;
#         }    #T_8c2afd1c_7a66_11eb_825a_e8d0fc9c55d2row1_col3 {
#             background-color:  #f8fcbd;
#             color:  #000000;
#         }    #T_8c2afd1c_7a66_11eb_825a_e8d0fc9c55d2row1_col4 {
#             background-color:  #a9db8c;
#             color:  #000000;
#         }    #T_8c2afd1c_7a66_11eb_825a_e8d0fc9c55d2row1_col5 {
#             background-color:  #9ad587;
#             color:  #000000;
#         }    #T_8c2afd1c_7a66_11eb_825a_e8d0fc9c55d2row1_col6 {
#             background-color:  #88cd7f;
#             color:  #000000;
#         }    #T_8c2afd1c_7a66_11eb_825a_e8d0fc9c55d2row1_col7 {
#             background-color:  #a9db8c;
#             color:  #000000;
#         }    #T_8c2afd1c_7a66_11eb_825a_e8d0fc9c55d2row1_col8 {
#             background-color:  #e9f6af;
#             color:  #000000;
#         }    #T_8c2afd1c_7a66_11eb_825a_e8d0fc9c55d2row2_col0 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_8c2afd1c_7a66_11eb_825a_e8d0fc9c55d2row2_col1 {
#             background-color:  #feffe1;
#             color:  #000000;
#         }    #T_8c2afd1c_7a66_11eb_825a_e8d0fc9c55d2row2_col2 {
#             background-color:  #004529;
#             color:  #f1f1f1;
#         }    #T_8c2afd1c_7a66_11eb_825a_e8d0fc9c55d2row2_col3 {
#             background-color:  #004d2c;
#             color:  #f1f1f1;
#         }    #T_8c2afd1c_7a66_11eb_825a_e8d0fc9c55d2row2_col4 {
#             background-color:  #3ea75a;
#             color:  #000000;
#         }    #T_8c2afd1c_7a66_11eb_825a_e8d0fc9c55d2row2_col5 {
#             background-color:  #329850;
#             color:  #000000;
#         }    #T_8c2afd1c_7a66_11eb_825a_e8d0fc9c55d2row2_col6 {
#             background-color:  #d6efa2;
#             color:  #000000;
#         }    #T_8c2afd1c_7a66_11eb_825a_e8d0fc9c55d2row2_col7 {
#             background-color:  #def2a7;
#             color:  #000000;
#         }    #T_8c2afd1c_7a66_11eb_825a_e8d0fc9c55d2row2_col8 {
#             background-color:  #006737;
#             color:  #f1f1f1;
#         }    #T_8c2afd1c_7a66_11eb_825a_e8d0fc9c55d2row3_col0 {
#             background-color:  #fafdcc;
#             color:  #000000;
#         }    #T_8c2afd1c_7a66_11eb_825a_e8d0fc9c55d2row3_col1 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_8c2afd1c_7a66_11eb_825a_e8d0fc9c55d2row3_col2 {
#             background-color:  #004d2c;
#             color:  #f1f1f1;
#         }    #T_8c2afd1c_7a66_11eb_825a_e8d0fc9c55d2row3_col3 {
#             background-color:  #004529;
#             color:  #f1f1f1;
#         }    #T_8c2afd1c_7a66_11eb_825a_e8d0fc9c55d2row3_col4 {
#             background-color:  #3fa85b;
#             color:  #000000;
#         }    #T_8c2afd1c_7a66_11eb_825a_e8d0fc9c55d2row3_col5 {
#             background-color:  #349a52;
#             color:  #000000;
#         }    #T_8c2afd1c_7a66_11eb_825a_e8d0fc9c55d2row3_col6 {
#             background-color:  #d3eda0;
#             color:  #000000;
#         }    #T_8c2afd1c_7a66_11eb_825a_e8d0fc9c55d2row3_col7 {
#             background-color:  #ddf1a6;
#             color:  #000000;
#         }    #T_8c2afd1c_7a66_11eb_825a_e8d0fc9c55d2row3_col8 {
#             background-color:  #0d733c;
#             color:  #f1f1f1;
#         }    #T_8c2afd1c_7a66_11eb_825a_e8d0fc9c55d2row4_col0 {
#             background-color:  #c5e89a;
#             color:  #000000;
#         }    #T_8c2afd1c_7a66_11eb_825a_e8d0fc9c55d2row4_col1 {
#             background-color:  #b5e092;
#             color:  #000000;
#         }    #T_8c2afd1c_7a66_11eb_825a_e8d0fc9c55d2row4_col2 {
#             background-color:  #329850;
#             color:  #000000;
#         }    #T_8c2afd1c_7a66_11eb_825a_e8d0fc9c55d2row4_col3 {
#             background-color:  #389f55;
#             color:  #000000;
#         }    #T_8c2afd1c_7a66_11eb_825a_e8d0fc9c55d2row4_col4 {
#             background-color:  #004529;
#             color:  #f1f1f1;
#         }    #T_8c2afd1c_7a66_11eb_825a_e8d0fc9c55d2row4_col5 {
#             background-color:  #006435;
#             color:  #f1f1f1;
#         }    #T_8c2afd1c_7a66_11eb_825a_e8d0fc9c55d2row4_col6 {
#             background-color:  #f8fcc0;
#             color:  #000000;
#         }    #T_8c2afd1c_7a66_11eb_825a_e8d0fc9c55d2row4_col7 {
#             background-color:  #f4fbb7;
#             color:  #000000;
#         }    #T_8c2afd1c_7a66_11eb_825a_e8d0fc9c55d2row4_col8 {
#             background-color:  #3da559;
#             color:  #000000;
#         }    #T_8c2afd1c_7a66_11eb_825a_e8d0fc9c55d2row5_col0 {
#             background-color:  #c7e89a;
#             color:  #000000;
#         }    #T_8c2afd1c_7a66_11eb_825a_e8d0fc9c55d2row5_col1 {
#             background-color:  #c1e698;
#             color:  #000000;
#         }    #T_8c2afd1c_7a66_11eb_825a_e8d0fc9c55d2row5_col2 {
#             background-color:  #2f944e;
#             color:  #000000;
#         }    #T_8c2afd1c_7a66_11eb_825a_e8d0fc9c55d2row5_col3 {
#             background-color:  #389f55;
#             color:  #000000;
#         }    #T_8c2afd1c_7a66_11eb_825a_e8d0fc9c55d2row5_col4 {
#             background-color:  #006837;
#             color:  #f1f1f1;
#         }    #T_8c2afd1c_7a66_11eb_825a_e8d0fc9c55d2row5_col5 {
#             background-color:  #004529;
#             color:  #f1f1f1;
#         }    #T_8c2afd1c_7a66_11eb_825a_e8d0fc9c55d2row5_col6 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_8c2afd1c_7a66_11eb_825a_e8d0fc9c55d2row5_col7 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_8c2afd1c_7a66_11eb_825a_e8d0fc9c55d2row5_col8 {
#             background-color:  #2f944e;
#             color:  #000000;
#         }    #T_8c2afd1c_7a66_11eb_825a_e8d0fc9c55d2row6_col0 {
#             background-color:  #4fb264;
#             color:  #000000;
#         }    #T_8c2afd1c_7a66_11eb_825a_e8d0fc9c55d2row6_col1 {
#             background-color:  #afde8f;
#             color:  #000000;
#         }    #T_8c2afd1c_7a66_11eb_825a_e8d0fc9c55d2row6_col2 {
#             background-color:  #ceeb9e;
#             color:  #000000;
#         }    #T_8c2afd1c_7a66_11eb_825a_e8d0fc9c55d2row6_col3 {
#             background-color:  #ddf1a6;
#             color:  #000000;
#         }    #T_8c2afd1c_7a66_11eb_825a_e8d0fc9c55d2row6_col4 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_8c2afd1c_7a66_11eb_825a_e8d0fc9c55d2row6_col5 {
#             background-color:  #ffffe5;
#             color:  #000000;

# %%
x = data.iloc[:, 0:7]

y = data.iloc[:, -1]

# %%
df_class_0 = x[data['CLASS'] == 0]
df_class_1 = x[data['CLASS'] == 1]

def plot_graph_attributes(attri):
    for i in attri:
        for j in attri:
            if i!=j:
                plt.figure(figsize=(3.5,3))
                plt.scatter(df_class_0[i], df_class_0[j], color="#76ead7", alpha=0.1, s=4)
                plt.scatter(df_class_1[i], df_class_1[j], color="#2814ba", alpha=0.1, s=4)
                plt.xlabel(i)
                plt.ylabel(j)

                plt.show()

# %%
attri=['MIP', 'SDIP', 'KIP', 'SIP', 'MDM']

plot_graph_attributes(attri)

# %%
def plot_histogram(attri):
    for i in attri:
        plt.hist(x=data[i], bins=50, color='orange',alpha=0.7, rwidth=0.85)
        plt.xlabel(i)
        plt.ylabel("frequency")
        plt.show()

# %%
plot_histogram(attri)

# %%
def plot_heat_map(attri):
    for i in attri:
        for j in attri:
            if i!=j:
                plt.hist2d(data[i], data[j], bins =40) 
                plt.xlabel(i)
                plt.ylabel(j)

                plt.show()

# %%
plot_heat_map(attri)
